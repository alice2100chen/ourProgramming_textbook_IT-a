# %% [markdown]
# 高山上氣溫

# %%
def temp(c, h):
    t = c - (h / 1000) * 6
    return t

x = temp(20,1545)
print(x)
# Out:
# 10.73

# %% [markdown]
# 高山上體感溫度

# %%
def temp(c, h, s):
    t = c - (h / 1000) * 6 - (s ** 0.5)
    return t

x = temp(20,1545, 12)
print(x)
# Out:
# 7.265898384862246
