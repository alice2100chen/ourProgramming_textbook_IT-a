# %%
beauty = ['西施','貂蟬','王昭君','楊貴妃','馮小憐','蘇妲己','趙飛燕','鄭旦','褒姒','甄宓']
c = len(beauty)               
t = input('請問芳名:')
for i in range(c):
    if beauty[i] == t:          
        print('發現搜尋目標', t, ', 位於清單中索引值為', i, '的位置')
# Out:
# 請問芳名:楊貴妃
# 發現搜尋目標 楊貴妃 , 位於清單中索引值為 3 的位置

# %%
beauty = ['西施','貂蟬','王昭君','楊貴妃','馮小憐','蘇妲己','趙飛燕','鄭旦','褒姒','甄宓']
c = len(beauty)               
t = input('請問芳名:')
found = -1
for i in range(c):
    if beauty[i] == t:          
        found = i
        print('發現搜尋目標', t, ', 位於清單中索引值為', found, '的位置') 

if found == -1:
    print('哭哭',t,'不在邀請名單上')
# Out:
# 請問芳名:楊玉環
# 哭哭 楊玉環 不在邀請名單上
