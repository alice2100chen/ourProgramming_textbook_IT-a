# %%
f = 77
c = (f-32) * (5/9)
print('攝氏:',c ,'度')
# Out:
# 攝氏: 25.0 度

# %%
if c < 20:
  print('畫畫')
elif c < 24:
  print('彈琴')
elif c < 27:
  print('下棋')
elif c < 30:
  print('賞花')
else:
  print('水療SPA')
# Out:
# 下棋
