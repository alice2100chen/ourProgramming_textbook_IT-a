# %%
def tatoo(s,num):
    for i in range(num):
       print(s[i])

s = ['★','☆','✪','✩','✫','✬','✭','✮','✯','✰','✡']
x = input('給一個數字:')
n = int(x)
if n > len(s):
   print('數字太大')
else:
   tatoo(s,n)
# Out:
# 給一個數字:12
# 數字太大
